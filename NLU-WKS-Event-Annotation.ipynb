# %%
# !pip install --upgrade "ibm-watson>=5.1.0"
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...
#      |████████████████████████████████| 409 kB 20.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 198 kB 47.5 MB/s eta 0:00:01
# ...
#   Created wheel for ibm-watson: filename=ibm_watson-5.2.0-py3-none-any.whl size=403239 sha256=d63a08e7742d5fa2144d3cadf5b83e5d2f8847cf41bedecf85a3b16728f683f9
#   Stored in directory: /tmp/wsuser/.cache/pip/wheels/a2/d9/83/2575af0d97f0a1e6ddb04877702ad79ade81caaa6e697a20ff
# ...

# %%
import json
import sys
import _thread
import time
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features,CategoriesOptions,EmotionOptions,KeywordsOptions

# %%
#NLU connection
#auth = IAMAuthenticator('TOlpC3xal_Yw-owNs_1EfIfUn1MofqT1qmZwJoMH7nOj')
#auth = IAMAuthenticator('PjbUXbntUmKtWWmMdKiuGEj1jHpV_Nv5SilFhsD8dxAf')
auth = IAMAuthenticator('8o_CqI8tLodR4h2jhNS-OanZs28MLlszPifEgZnl11qa')

natural_language_understanding = NaturalLanguageUnderstandingV1(version='2020-08-01', authenticator=auth)
#natural_language_understanding.set_service_url('https://api.us-south.natural-language-understanding.watson.cloud.ibm.com/instances/f982b484-7309-4dde-b76c-c984024c606c')
#natural_language_understanding.set_service_url('https://api.us-south.natural-language-understanding.watson.cloud.ibm.com/instances/38ea2605-d0ab-487b-ba24-36035390336a')
natural_language_understanding.set_service_url('https://api.us-south.natural-language-understanding.watson.cloud.ibm.com/instances/3bc91c4e-3c0c-412c-bd9e-9b1d64ea3d45')


#model_id='35f14ff0-73bc-433b-a742-5d3b25676920'
#model_id='4d6400df-51eb-4518-a9f9-9510894fb0bd'
#model_id='f5091b29-ba88-4c9f-a613-472a8a2d67d7'
model_id='fbbe02c9-307b-40d8-8998-d4a6c710af18'

#get wks output
def getNLUResult(content):
    global natural_language_understanding
    response = natural_language_understanding.analyze(
        text=content,
        features={
            'entities': {
                #'model': model_id
            },
            'relations': {
                #'model': model_id
            }
        }
    ).get_result()  
    return response

#result = getNLUResult("Valentines Day Offer, get Rs.10000 cashback + No Cost EMI on all models of iPad. Valid till Feb 14 at your nearest Imagine. https://goo.gl/hFJcfk")
#result = getNLUResult("My wife XXX was traveling west on great eastern highway with our daughter XXX It was raining she was traveling at approx 70km/h in an 80km/h zone due to the weather. Another car was traveling east when suddenly the other vehicle veered at speed across the median strip into the path of my wifes car. His car spun and ended up facing west in the right lane in front of our car. She hit the brakes but had insufficient time to stop and our car collided with the other car. My wife rolled the car down the hill to a safe place to pull over. The other driver ran down to my wife and daughter to see if they were OK and said he was sorry but that he had lost control of his car. He then ran off. The ambulance and police arrived. My wife and daughter were examined on the scene and then taken to Midland where they were further examined. Thankfully it would appear that they have only had minor injuries. I tried calling AAMI but was cut off. Our vehicle was towed by Lightning Towing to their yard in Midland.")
result = getNLUResult("We drove home after a weekend at a Kalbarri resort. Suddenly a number of kangaroos (five or even six) appeared in the road in front of us and despite breaking hard in an effort to stop I was unable to avoid a collision with two or possibly three of the animals at considerable speed. Conditions where such that we could not pull off the road due to soft shoulders and I slowly continued until we found a safe spot to stop. Upon inspection we noticed a number of panels had come off the bumper and the bumper also seemed to have some minor damage. Most of the damage is on the left side where it seems that the side metal panel also had damage. All the lights were still working and when driving further no warning lights came on. The vehicle seemed to have a shudder of sorts from the wheels or gearbox when accelerating and the steering column hangs to the right but it is not clear whether or how this is related to the accident exactly. I have a suspicion the wheel alignment might have been affected.")
print(json.dumps(result, indent=4))
# Out:
# {
#     "usage": {
#         "text_units": 1,
#         "text_characters": 1004,
#         "features": 2
#     },
#     "relations": [
#         {
#             "type": "locatedAt",
#             "sentence": "We drove home after a weekend at a Kalbarri resort.",
#             "score": 0.909109,
#             "arguments": [
#                 {
#                     "text": "resort",
#                     "location": [
#                         44,
#                         50
#                     ],
#                     "entities": [
#                         {
#                             "type": "Facility",
#                             "text": "resort"
#                         }
#                     ]
#                 },
#                 {
#                     "text": "Kalbarri",
#                     "location": [
#                         35,
#                         43
#                     ],
#                     "entities": [
#                         {
# ...
